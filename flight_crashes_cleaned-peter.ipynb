# %% [markdown]
# # Import and Initialize

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)
import numpy as np
import seaborn as sns
from fuzzywuzzy import fuzz

file_path = "/Users/peterwilliams/Downloads/PlaneCrashes/PlaneCrashes.csv"

df = pd.read_csv(file_path)
df = pd.DataFrame(df)

# %% [markdown]
# # Cleaning

# %%
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df.columns = pd.Series(df.columns).apply(lambda col: col.lower())
df.dropna(how='all', inplace= True)
df.fillna("unknown", inplace = True)
df.columns = df.columns.str.replace(' ', '_')
df['crew_on_board'] = df['crew_on_board'].replace('unknown', '0.0')
df['crew_on_board'] = pd.to_numeric(df['crew_on_board'], errors='coerce')

df['pax_on_board'] = df['pax_on_board'].replace('unknown', '0.0')
df['pax_on_board'] = pd.to_numeric(df['pax_on_board'], errors='coerce')

df['crew_fatalities'] = df['crew_fatalities'].replace('unknown', '0.0')
df['crew_fatalities'] = pd.to_numeric(df['crew_fatalities'], errors='coerce')

df['pax_fatalities'] = df['pax_fatalities'].replace('unknown', '0.0')
df['pax_fatalities'] = pd.to_numeric(df['pax_fatalities'], errors='coerce')

df['other_fatalities'] = df['other_fatalities'].replace('unknown', '0.0')
df['other_fatalities'] = pd.to_numeric(df['other_fatalities'], errors='coerce')

# %%
df.drop(['msn',
         'yom',
         'flight_no.', 
        ], axis=1, inplace=True)

# %%
df['total_on_board'] = df['crew_on_board'] + df['pax_on_board']
df['total_fatalities'] = df['crew_fatalities'] + df['pax_fatalities'] + df['other_fatalities']

# %%
df_cleaned = df.drop(['crew_on_board', 'crew_fatalities', 'pax_on_board', 'pax_fatalities', 'other_fatalities'], axis=1)

# %%
df_cleaned
# Out:
#              date        time                              aircraft  \
# 0      1918-05-02     unknown                     de havilland dh.4
# 1      1918-06-08     unknown                   handley page v/1500
# 2      1918-06-11     unknown                              avro 504
# 3      1918-06-19     unknown                     de havilland dh.4
# 4      1918-06-24     unknown                            breguet 14
# ...           ...         ...                                   ...
# 28531  2022-05-20     unknown           embraer emb-110 bandeirante
# 28532  2022-05-23  18h 29m 0s  piper pa-61 aerostar (ted smith 601)
# 28533  2022-05-24  15h 40m 0s              de havilland dhc-3 otter
# 28534  2022-05-29   10h 7m 0s         de havilland dhc-6 twin otter
# 28535  2022-06-03  13h 46m 0s             cessna 208b grand caravan
#
#                                 operator registration  \
# 0      united states signal corps - ussc     as-32084
# 1      handley page aircraft company ltd        e4104
# 2                  royal air force - raf        a8544
# 3      united states signal corps - ussc     as-32098
# 4      french air force - armée de l'air      as-4130
# ...                                  ...          ...
# 28531              sales serviços aéreos       pt-shn
# 28532               raul ignacion posada        n66cg
# 28533           yakutat coastal airlines       n703th
# 28534                           tara air       9n-aet
# 28535                   gojump oceanside       n7581f
#
#                         flight_phase  \
# 0                    takeoff (climb)
# 1                    takeoff (climb)
# 2                             flight
# 3                             flight
# 4      landing (descent or approach)
# ...                              ...
# 28531  landing (descent or approach)
# 28532                         flight
# 28533  landing (descent or approach)
# 28534                         flight
# 28535  landing (descent or approach)
#
#                                        flight_type survivors  \
# 0                                             test        no
# 1                                             test       yes
# 2                                         training       yes
# 3                                         military        no
# 4                                         military       yes
# ...                                            ...       ...
# 28531                                        cargo       yes
# 28532                                      private        no
# 28533  charter/taxi (non scheduled revenue flight)       yes
# 28534                     scheduled revenue flight        no
# 28535                     skydiving / paratroopers       yes
#
#                                    crash_site  \
# 0      airport (less than 10 km from airport)
# 1      airport (less than 10 km from airport)
# 2                               plain, valley
# 3      airport (less than 10 km from airport)
# 4                                     unknown
# ...                                       ...
# 28531  airport (less than 10 km from airport)
# 28532                           plain, valley
# 28533  airport (less than 10 km from airport)
# 28534                               mountains
# 28535  airport (less than 10 km from airport)
#
#                                         schedule  \
# 0                                dayton - dayton
# 1                      cricklewood - cricklewood
# 2                                abukir - abukir
# 3      wright patterson afb-wright patterson afb
# 4                                        unknown
# ...                                          ...
# 28531                  jundiaí – eldorado do sul
# 28532                           celaya - durango
# 28533                          yakutat – dry bay
# 28534                           pokhara – jomsom
# 28535                      oceanside - oceanside
#
#                            crash_location                   country  \
# 0                dayton-mccook field ohio  united states of america
# 1           cricklewood london metropolis            united kingdom
# 2             abukir (abu qir) alexandria                     egypt
# 3      wright-patterson afb (dayton) ohio  united states of america
# 4                       france all france                    france
# ...                                   ...                       ...
# 28531   eldorado do sul rio grande do sul                    brazil
# 28532                     durango durango                    mexico
# 28533                      dry bay alaska  united states of america
# 28534                  shikha dhawalagiri                     nepal
# 28535                oceanside california  united states of america
#
#                 region  total_fatalities  \
# 0        north america               2.0
# 1               europe               5.0
# 2               africa               1.0
# 3        north america               1.0
# 4               europe               0.0
# ...                ...               ...
# 28531    south america               0.0
# 28532  central america               2.0
# 28533    north america               0.0
# 28534             asia              22.0
# 28535    north america               1.0
#
#                                            circumstances        crash_cause  \
# 0      the single engine airplane departed dayton-mcc...  technical failure
# 1      assembled at cricklewood airfield in may 1918,...  technical failure
# 2      the single engine aircraft was completing a lo...            unknown
# 3      lt. frank stuart patterson, son and nephew of ...  technical failure
# 4      the aircraft crashed iupon landing somewhere i...            unknown
# ...                                                  ...                ...
# 28531  the airplane departed jundiaí on a cargo fligh...            unknown
# 28532  while approaching durango airport on a flight ...            unknown
# 28533  the single engine airplane departed yakutat on...            unknown
# 28534  the twin engine airplane departed pokhara city...       human factor
# 28535  the single engine was completing local skydivi...            unknown
#
#        total_on_board
# 0                 2.0
# 1                 6.0
# 2                 2.0
# 3                 1.0
# 4                 0.0
# ...               ...
# 28531             2.0
# 28532             2.0
# 28533             4.0
# 28534            22.0
# 28535             2.0
#
# [28536 rows x 17 columns]

# %%
order = [
    "date", "time", "aircraft", "operator", "flight_phase",
    "flight_type", "crash_site", "schedule", "crash_location",
    "country", "region", "circumstances", "crash_cause",
    "total_on_board", "total_fatalities", "survivors"
]

# %%
df_cleaned = df_cleaned[order]

# %%
df_cleaned
# Out:
#              date        time                              aircraft  \
# 0      1918-05-02     unknown                     de havilland dh.4
# 1      1918-06-08     unknown                   handley page v/1500
# 2      1918-06-11     unknown                              avro 504
# 3      1918-06-19     unknown                     de havilland dh.4
# 4      1918-06-24     unknown                            breguet 14
# ...           ...         ...                                   ...
# 28531  2022-05-20     unknown           embraer emb-110 bandeirante
# 28532  2022-05-23  18h 29m 0s  piper pa-61 aerostar (ted smith 601)
# 28533  2022-05-24  15h 40m 0s              de havilland dhc-3 otter
# 28534  2022-05-29   10h 7m 0s         de havilland dhc-6 twin otter
# 28535  2022-06-03  13h 46m 0s             cessna 208b grand caravan
#
#                                 operator                   flight_phase  \
# 0      united states signal corps - ussc                takeoff (climb)
# 1      handley page aircraft company ltd                takeoff (climb)
# 2                  royal air force - raf                         flight
# 3      united states signal corps - ussc                         flight
# 4      french air force - armée de l'air  landing (descent or approach)
# ...                                  ...                            ...
# 28531              sales serviços aéreos  landing (descent or approach)
# 28532               raul ignacion posada                         flight
# 28533           yakutat coastal airlines  landing (descent or approach)
# 28534                           tara air                         flight
# 28535                   gojump oceanside  landing (descent or approach)
#
#                                        flight_type  \
# 0                                             test
# 1                                             test
# 2                                         training
# 3                                         military
# 4                                         military
# ...                                            ...
# 28531                                        cargo
# 28532                                      private
# 28533  charter/taxi (non scheduled revenue flight)
# 28534                     scheduled revenue flight
# 28535                     skydiving / paratroopers
#
#                                    crash_site  \
# 0      airport (less than 10 km from airport)
# 1      airport (less than 10 km from airport)
# 2                               plain, valley
# 3      airport (less than 10 km from airport)
# 4                                     unknown
# ...                                       ...
# 28531  airport (less than 10 km from airport)
# 28532                           plain, valley
# 28533  airport (less than 10 km from airport)
# 28534                               mountains
# 28535  airport (less than 10 km from airport)
#
#                                         schedule  \
# 0                                dayton - dayton
# 1                      cricklewood - cricklewood
# 2                                abukir - abukir
# 3      wright patterson afb-wright patterson afb
# 4                                        unknown
# ...                                          ...
# 28531                  jundiaí – eldorado do sul
# 28532                           celaya - durango
# 28533                          yakutat – dry bay
# 28534                           pokhara – jomsom
# 28535                      oceanside - oceanside
#
#                            crash_location                   country  \
# 0                dayton-mccook field ohio  united states of america
# 1           cricklewood london metropolis            united kingdom
# 2             abukir (abu qir) alexandria                     egypt
# 3      wright-patterson afb (dayton) ohio  united states of america
# 4                       france all france                    france
# ...                                   ...                       ...
# 28531   eldorado do sul rio grande do sul                    brazil
# 28532                     durango durango                    mexico
# 28533                      dry bay alaska  united states of america
# 28534                  shikha dhawalagiri                     nepal
# 28535                oceanside california  united states of america
#
#                 region                                      circumstances  \
# 0        north america  the single engine airplane departed dayton-mcc...
# 1               europe  assembled at cricklewood airfield in may 1918,...
# 2               africa  the single engine aircraft was completing a lo...
# 3        north america  lt. frank stuart patterson, son and nephew of ...
# 4               europe  the aircraft crashed iupon landing somewhere i...
# ...                ...                                                ...
# 28531    south america  the airplane departed jundiaí on a cargo fligh...
# 28532  central america  while approaching durango airport on a flight ...
# 28533    north america  the single engine airplane departed yakutat on...
# 28534             asia  the twin engine airplane departed pokhara city...
# 28535    north america  the single engine was completing local skydivi...
#
#              crash_cause  total_on_board  total_fatalities survivors
# 0      technical failure             2.0               2.0        no
# 1      technical failure             6.0               5.0       yes
# 2                unknown             2.0               1.0       yes
# 3      technical failure             1.0               1.0        no
# 4                unknown             0.0               0.0       yes
# ...                  ...             ...               ...       ...
# 28531            unknown             2.0               0.0       yes
# 28532            unknown             2.0               2.0        no
# 28533            unknown             4.0               0.0       yes
# 28534       human factor            22.0              22.0        no
# 28535            unknown             2.0               1.0       yes
#
# [28536 rows x 16 columns]

# %% [markdown]
# # Certain routes have a higher risk factor of fatalities

# %%
df_cleaned
# Out:
#              date        time                              aircraft  \
# 0      1918-05-02     unknown                     de havilland dh.4
# 1      1918-06-08     unknown                   handley page v/1500
# 2      1918-06-11     unknown                              avro 504
# 3      1918-06-19     unknown                     de havilland dh.4
# 4      1918-06-24     unknown                            breguet 14
# ...           ...         ...                                   ...
# 28531  2022-05-20     unknown           embraer emb-110 bandeirante
# 28532  2022-05-23  18h 29m 0s  piper pa-61 aerostar (ted smith 601)
# 28533  2022-05-24  15h 40m 0s              de havilland dhc-3 otter
# 28534  2022-05-29   10h 7m 0s         de havilland dhc-6 twin otter
# 28535  2022-06-03  13h 46m 0s             cessna 208b grand caravan
#
#                                 operator                   flight_phase  \
# 0      united states signal corps - ussc                takeoff (climb)
# 1      handley page aircraft company ltd                takeoff (climb)
# 2                  royal air force - raf                         flight
# 3      united states signal corps - ussc                         flight
# 4      french air force - armée de l'air  landing (descent or approach)
# ...                                  ...                            ...
# 28531              sales serviços aéreos  landing (descent or approach)
# 28532               raul ignacion posada                         flight
# 28533           yakutat coastal airlines  landing (descent or approach)
# 28534                           tara air                         flight
# 28535                   gojump oceanside  landing (descent or approach)
#
#                                        flight_type  \
# 0                                             test
# 1                                             test
# 2                                         training
# 3                                         military
# 4                                         military
# ...                                            ...
# 28531                                        cargo
# 28532                                      private
# 28533  charter/taxi (non scheduled revenue flight)
# 28534                     scheduled revenue flight
# 28535                     skydiving / paratroopers
#
#                                    crash_site  \
# 0      airport (less than 10 km from airport)
# 1      airport (less than 10 km from airport)
# 2                               plain, valley
# 3      airport (less than 10 km from airport)
# 4                                     unknown
# ...                                       ...
# 28531  airport (less than 10 km from airport)
# 28532                           plain, valley
# 28533  airport (less than 10 km from airport)
# 28534                               mountains
# 28535  airport (less than 10 km from airport)
#
#                                         schedule  \
# 0                                dayton - dayton
# 1                      cricklewood - cricklewood
# 2                                abukir - abukir
# 3      wright patterson afb-wright patterson afb
# 4                                        unknown
# ...                                          ...
# 28531                  jundiaí – eldorado do sul
# 28532                           celaya - durango
# 28533                          yakutat – dry bay
# 28534                           pokhara – jomsom
# 28535                      oceanside - oceanside
#
#                            crash_location                   country  \
# 0                dayton-mccook field ohio  united states of america
# 1           cricklewood london metropolis            united kingdom
# 2             abukir (abu qir) alexandria                     egypt
# 3      wright-patterson afb (dayton) ohio  united states of america
# 4                       france all france                    france
# ...                                   ...                       ...
# 28531   eldorado do sul rio grande do sul                    brazil
# 28532                     durango durango                    mexico
# 28533                      dry bay alaska  united states of america
# 28534                  shikha dhawalagiri                     nepal
# 28535                oceanside california  united states of america
#
#                 region                                      circumstances  \
# 0        north america  the single engine airplane departed dayton-mcc...
# 1               europe  assembled at cricklewood airfield in may 1918,...
# 2               africa  the single engine aircraft was completing a lo...
# 3        north america  lt. frank stuart patterson, son and nephew of ...
# 4               europe  the aircraft crashed iupon landing somewhere i...
# ...                ...                                                ...
# 28531    south america  the airplane departed jundiaí on a cargo fligh...
# 28532  central america  while approaching durango airport on a flight ...
# 28533    north america  the single engine airplane departed yakutat on...
# 28534             asia  the twin engine airplane departed pokhara city...
# 28535    north america  the single engine was completing local skydivi...
#
#              crash_cause  total_on_board  total_fatalities survivors
# 0      technical failure             2.0               2.0        no
# 1      technical failure             6.0               5.0       yes
# 2                unknown             2.0               1.0       yes
# 3      technical failure             1.0               1.0        no
# 4                unknown             0.0               0.0       yes
# ...                  ...             ...               ...       ...
# 28531            unknown             2.0               0.0       yes
# 28532            unknown             2.0               2.0        no
# 28533            unknown             4.0               0.0       yes
# 28534       human factor            22.0              22.0        no
# 28535            unknown             2.0               1.0       yes
#
# [28536 rows x 16 columns]

# %%
df_cleaned["flight_type"].unique()
# Out:
# array(['test', 'training', 'military', 'delivery',
#        'survey / patrol / reconnaissance', 'postal (mail)', 'ferry',
#        'aerial photography', 'scheduled revenue flight', 'government',
#        'private', 'charter/taxi (non scheduled revenue flight)',
#        'unknown', 'cargo', 'positioning', 'demonstration', 'ambulance',
#        'executive/corporate/business', 'topographic',
#        'geographical / geophysical / scientific', 'cinematography',
#        'illegal (smuggling)', 'spraying (agricultural)', 'refuelling',
#        'humanitarian', 'bombing', 'supply', 'calibration',
#        'meteorological / weather', 'fire fighting',
#        'skydiving / paratroopers', 'aerobatic'], dtype=object)

# %%
df_cleaned["schedule"].nunique()
# Out:
# 15657

# %%
df_sorted = df.sort_values(by='Score', ascending=False)

print(df_sorted)

# %%
count number of roputes
