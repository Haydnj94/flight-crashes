# %% [markdown]
# # Import and Initialize

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)
import numpy as np
import seaborn as sns
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from openpyxl import load_workbook

file_path = '/Users/haydnjones/Documents/GitHub/flight-crashes/Plane Crashes.csv'

df = pd.read_csv(file_path)
df = pd.DataFrame(df)

# %% [markdown]
# # Cleaning

# %%
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df.columns = pd.Series(df.columns).apply(lambda col: col.lower())
df.dropna(how='all', inplace= True)
df.fillna("unknown", inplace = True)
df.columns = df.columns.str.replace(' ', '_')

df['crew_on_board'] = df['crew_on_board'].replace('unknown', '0.0')
df['crew_on_board'] = pd.to_numeric(df['crew_on_board'], errors='coerce')

df['pax_on_board'] = df['pax_on_board'].replace('unknown', '0.0')
df['pax_on_board'] = pd.to_numeric(df['pax_on_board'], errors='coerce')

df['crew_fatalities'] = df['crew_fatalities'].replace('unknown', '0.0')
df['crew_fatalities'] = pd.to_numeric(df['crew_fatalities'], errors='coerce')

df['pax_fatalities'] = df['pax_fatalities'].replace('unknown', '0.0')
df['pax_fatalities'] = pd.to_numeric(df['pax_fatalities'], errors='coerce')

df['other_fatalities'] = df['other_fatalities'].replace('unknown', '0.0')
df['other_fatalities'] = pd.to_numeric(df['other_fatalities'], errors='coerce')

df['total_on_board'] = df['crew_on_board'] + df['pax_on_board']
df['total_fatalities'] = df['crew_fatalities'] + df['pax_fatalities'] + df['other_fatalities']

df_cleaned = df.drop(['crew_on_board', 'crew_fatalities', 'pax_on_board', 'pax_fatalities', 'other_fatalities', 'yom', 'msn', 'flight_no.'], axis=1)

order = [
    "date", "time", "aircraft", "operator", "flight_phase",
    "flight_type", "crash_site", "schedule", "crash_location",
    "country", "region", "circumstances", "crash_cause",
    "total_on_board", "total_fatalities", "survivors"
]

df_cleaned = df_cleaned[order]

# %%
passenger_types = [
    "scheduled revenue flight",
    "charter/taxi (non scheduled revenue flight)",
    "private",
    "executive/corporate/business",
    "ferry"
    "cargo",
    "positioning",
    "ambulance",
    "topographic",
    "geographical / geophysical / scientific",
    "illegal (smuggling)",
    "spraying (agricultural)",
    "humanitarian",
    "meteorological / weather",
    "fire fighting"
]

df_cleaned['flight_type'] = df_cleaned['flight_type'].apply(lambda x: 'passenger flights' if x in passenger_types else None)

df_cleaned = df_cleaned.dropna(subset=['flight_type'])

# %%
threshold_year = 1950

df_cleaned['date'] = pd.to_datetime(df_cleaned['date'])
df_cleaned = df_cleaned[df_cleaned['date'].dt.year >= threshold_year]

# %% [markdown]
# # Fatal Routes

# %% [markdown]
# ## Wrangling

# %%
df_routes = df_cleaned.sort_values(by='schedule', ascending=False)

df_routes
# Out:
#             date        time                              aircraft  \
# 13738 1965-08-25  21h 30m 0s                       pzl-mielec an-2
# 26868 2011-03-02    9h 5m 0s            swearingen sa227 metro iii
# 21521 1989-01-21  17h 47m 0s             swearingen sa226 metro ii
# 16791 1974-09-15   11h 0m 0s                        boeing 727-100
# 14146 1967-01-12     unknown  pilatus pc-6 (porter & turbo porter)
# ...          ...         ...                                   ...
# 20686 1986-05-21  15h 21m 0s                        tupolev tu-154
# 10382 1952-12-25     unknown          douglas c-47 skytrain (dc-3)
# 11221 1955-09-14     unknown                         avro 685 york
# 26669 2010-01-24   7h 20m 0s                        tupolev tu-154
# 24239 1998-10-12  23h 25m 0s                            cessna 402
#
#                                         operator  \
# 13738  aeroflot - russian international airlines
# 26868                                 air norway
# 21521                                    muk air
# 16791                                air vietnam
# 14146                                air america
# ...                                          ...
# 20686  aeroflot - russian international airlines
# 10382                                   iran air
# 11221                       persian air services
# 26669                             taban airlines
# 24239                      jetair flight academy
#
#                         flight_phase        flight_type  \
# 13738                         flight  passenger flights
# 26868  landing (descent or approach)  passenger flights
# 21521  landing (descent or approach)  passenger flights
# 16791  landing (descent or approach)  passenger flights
# 14146                         flight  passenger flights
# ...                              ...                ...
# 20686  landing (descent or approach)  passenger flights
# 10382  landing (descent or approach)  passenger flights
# 11221                         flight  passenger flights
# 26669  landing (descent or approach)  passenger flights
# 24239  landing (descent or approach)  passenger flights
#
#                                    crash_site  \
# 13738                           plain, valley
# 26868  airport (less than 10 km from airport)
# 21521  airport (less than 10 km from airport)
# 16791  airport (less than 10 km from airport)
# 14146                               mountains
# ...                                       ...
# 20686  airport (less than 10 km from airport)
# 10382  airport (less than 10 km from airport)
# 11221                                  desert
# 26669  airport (less than 10 km from airport)
# 24239  airport (less than 10 km from airport)
#
#                                   schedule  \
# 13738                      šilale - šilale
# 26868                        ørland - oslo
# 21521                örnsköldsvik - örebro
# 16791  ðà n<u+1eb5>ng – saigon – singapore
# 14146   ðà n<u+1eb5>ng – qu<u+1ea3>ng ngãi
# ...                                    ...
# 20686        abakan - chelyabinsk - moscow
# 10382                     abadan – téhéran
# 11221                 abadan – kuwait city
# 26669                     abadan - machhad
# 24239                      aalborg - stord
#
#                                           crash_location    country  region  \
# 13738                        šilale apskritis of taurage  lithuania  europe
# 26868                           oslo-gardermoen akershus     norway  europe
# 21521                          örnsköldsvik ångermanland     sweden  europe
# 16791               phan rang ninh thu<u+1ead>n province    vietnam    asia
# 14146                  chu lai qu<u+1ea3>ng nam province    vietnam    asia
# ...                                                  ...        ...     ...
# 20686                  moscow-sheremetyevo moscow oblast     russia    asia
# 10382                        tehran tehran city district       iran    asia
# 11221  al seeba al-basrah (<u+0627><u+0644><u+0628><u...       iraq    asia
# 26669                            mashhad razavi khorasan       iran    asia
# 24239                         stord-sørstokken hordaland     norway  europe
#
#                                            circumstances  \
# 13738  following crop-spraying operations in the regi...
# 26868  after touchdown on runway 19r at oslo-gardermo...
# 21521  after takeoff from örnsköldsvik airport, while...
# 16791  en route from ðà n<u+1eb5>ng to saigon, while ...
# 14146  while cruising in poor weather conditions, the...
# ...                                                  ...
# 20686  following an uneventful flight from chelyabins...
# 10382  while descending to tehran-mehrabad airport in...
# 11221  about eight minutes after takeoff from abadan ...
# 26669  the three engine aircraft departed abadan for ...
# 24239  on final approach to stord-sørstokken airport ...
#
#                               crash_cause  total_on_board  total_fatalities  \
# 13738                        human factor             1.0               1.0
# 26868                   technical failure            11.0               0.0
# 21521                   technical failure            17.0               0.0
# 16791  terrorism act, hijacking, sabotage            75.0              75.0
# 14146                             weather             5.0               5.0
# ...                                   ...             ...               ...
# 20686                             weather           185.0               0.0
# 10382                   technical failure            29.0              27.0
# 11221                        human factor            13.0               0.0
# 26669                        human factor           170.0               0.0
# 24239                   technical failure             9.0               9.0
#
#       survivors
# 13738        no
# 26868       yes
# 21521       yes
# 16791        no
# 14146        no
# ...         ...
# 20686       yes
# 10382       yes
# 11221       yes
# 26669       yes
# 24239        no
#
# [10696 rows x 16 columns]

# %%
df_routes = df_cleaned.groupby("schedule")[["total_fatalities"]].sum().sort_values(by="total_fatalities", ascending=False).head(21)
df_routes = df_routes.iloc[1:]
df_routes
# Out:
#                                                     total_fatalities
# schedule
# tokyo - osaka                                                  520.0
# ankara - paris - london                                        346.0
# los angeles – new york – las palmas                            335.0
# vancouver – toronto – montreal – london – new d...             329.0
# new delhi - dhahran - jeddah                                   312.0
# karachi - riyadh - jeddah                                      301.0
# amsterdam – kuala lumpur                                       298.0
# bandar abbas – dubai                                           290.0
# karachi - islamabad                                            279.0
# chicago - los angeles                                          273.0
# london - new york                                              270.0
# new york - anchorage - seoul                                   269.0
# new york - santo domingo                                       265.0
# taipei - nagoya                                                264.0
# jeddah - sokoto                                                261.0
# auckland - christchurch                                        257.0
# cairo – cologne – gander – fort campbell                       256.0
# guangzhou - guilin                                             253.0
# taipei - hong kong                                             250.0
# tenerife - las palmas                                          248.0

# %% [markdown]
# ## Charts

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x="schedule",y = "total_fatalities", data=df_routes, palette="coolwarm_r")
plt.title("Fatalities by Route")
plt.xticks(rotation=90)
plt.xlabel("Schedule")
plt.ylabel("Total Fatalities")
df_routes_reversed = df_routes.iloc[::-1]

# %%
df_routes["total_fatalities"].mean()
# Out:
# 293.8

# %%
df_routes.mean()
# Out:
# total_fatalities    293.8
# dtype: float64

# %%
df_routes.describe()
# Out:
#        total_fatalities
# count         20.000000
# mean         293.800000
# std           60.841987
# min          248.000000
# 25%          260.000000
# 50%          271.500000
# 75%          303.750000
# max          520.000000

# %%
df_routes.sum()
# Out:
# total_fatalities    5876.0
# dtype: float64

# %% [markdown]
# # Distance of Crash from Airport

# %% [markdown]
# ## Wrangling

# %%
df_cleaned.keys()
# Out:
# Index(['date', 'time', 'aircraft', 'operator', 'flight_phase', 'flight_type',
#        'crash_site', 'schedule', 'crash_location', 'country', 'region',
#        'circumstances', 'crash_cause', 'total_on_board', 'total_fatalities',
#        'survivors'],
#       dtype='object')

# %%
df_cleaned
# Out:
#             date        time                              aircraft  \
# 9071  1950-01-03     unknown                        avro 652 anson
# 9075  1950-01-07     unknown                            boeing 247
# 9081  1950-01-14     unknown      de havilland dh.89 dragon rapide
# 9082  1950-01-18     unknown                          douglas dc-3
# 9086  1950-01-22     unknown              de havilland dh.104 dove
# ...          ...         ...                                   ...
# 28529 2022-05-11     unknown         de havilland dhc-6 twin otter
# 28530 2022-05-12    8h 4m 0s                           airbus a319
# 28532 2022-05-23  18h 29m 0s  piper pa-61 aerostar (ted smith 601)
# 28533 2022-05-24  15h 40m 0s              de havilland dhc-3 otter
# 28534 2022-05-29   10h 7m 0s         de havilland dhc-6 twin otter
#
#                                      operator                   flight_phase  \
# 9071           united air services - tanzania  landing (descent or approach)
# 9075   lineas aéreas guerrero oaxaca - lagosa                takeoff (climb)
# 9081             new zealand national airways                        parking
# 9082             trans asiatic airlines - taa                takeoff (climb)
# 9086            central african airways - caa  landing (descent or approach)
# ...                                       ...                            ...
# 28529                    caverton helicopters                         flight
# 28530                          tibet airlines                takeoff (climb)
# 28532                    raul ignacion posada                         flight
# 28533                yakutat coastal airlines  landing (descent or approach)
# 28534                                tara air                         flight
#
#              flight_type                              crash_site  \
# 9071   passenger flights                           plain, valley
# 9075   passenger flights                           plain, valley
# 9081   passenger flights  airport (less than 10 km from airport)
# 9082   passenger flights  airport (less than 10 km from airport)
# 9086   passenger flights  airport (less than 10 km from airport)
# ...                  ...                                     ...
# 28529  passenger flights                           plain, valley
# 28530  passenger flights  airport (less than 10 km from airport)
# 28532  passenger flights                           plain, valley
# 28533  passenger flights  airport (less than 10 km from airport)
# 28534  passenger flights                               mountains
#
#                         schedule                               crash_location  \
# 9071                     unknown                     kazimzumbwi pwani region
# 9075                     unknown  mexico city federal district of mexico city
# 9081          rotorua – hamilton       rotorua bay of plenty regional council
# 9082                     unknown                         yangon yangon region
# 9086                     unknown                         livingstone southern
# ...                          ...                                          ...
# 28529  yaoundé – dompta – belabo                           nanga eboko centre
# 28530       chongqing – nyingchi                   chongqing-jiangbei sichuan
# 28532           celaya - durango                              durango durango
# 28533          yakutat – dry bay                               dry bay alaska
# 28534           pokhara – jomsom                           shikha dhawalagiri
#
#                         country           region  \
# 9071                   tanzania           africa
# 9075                     mexico  central america
# 9081                new zealand          oceania
# 9082                    myanmar             asia
# 9086                     zambia           africa
# ...                         ...              ...
# 28529                  cameroon           africa
# 28530                     china             asia
# 28532                    mexico  central america
# 28533  united states of america    north america
# 28534                     nepal             asia
#
#                                            circumstances        crash_cause  \
# 9071   while approaching dar es-salaam, the twin engi...            unknown
# 9075   few minutes after takeoff from mexico city, th...            unknown
# 9081   the aircraft was parked at rotorua airport and...  technical failure
# 9082   an undercarriage failed during takeoff roll. t...  technical failure
# 9086   crashed on final approach to livingstone airpo...            unknown
# ...                                                  ...                ...
# 28529  the twin engine airplane departed yaoundé at 1...            unknown
# 28530  the airplane was departing chongqing-jiangbei ...            unknown
# 28532  while approaching durango airport on a flight ...            unknown
# 28533  the single engine airplane departed yakutat on...            unknown
# 28534  the twin engine airplane departed pokhara city...       human factor
#
#        total_on_board  total_fatalities survivors
# 9071              2.0               2.0        no
# 9075              0.0               0.0   unknown
# 9081              5.0               0.0       yes
# 9082              0.0               0.0       yes
# 9086              0.0               0.0   unknown
# ...               ...               ...       ...
# 28529            11.0              11.0        no
# 28530           122.0               0.0       yes
# 28532             2.0               2.0        no
# 28533             4.0               0.0       yes
# 28534            22.0              22.0        no
#
# [10696 rows x 16 columns]

# %%
df_cleaned["crash_site"].unique()
# Out:
# array(['plain, valley', 'airport (less than 10 km from airport)',
#        'mountains', 'lake, sea, ocean, river', 'desert', 'unknown',
#        'city'], dtype=object)

# %%
df_cleaned.sort_values(by="crash_site", ascending=False)
df_cleaned
# Out:
#             date        time                              aircraft  \
# 9071  1950-01-03     unknown                        avro 652 anson
# 9075  1950-01-07     unknown                            boeing 247
# 9081  1950-01-14     unknown      de havilland dh.89 dragon rapide
# 9082  1950-01-18     unknown                          douglas dc-3
# 9086  1950-01-22     unknown              de havilland dh.104 dove
# ...          ...         ...                                   ...
# 28529 2022-05-11     unknown         de havilland dhc-6 twin otter
# 28530 2022-05-12    8h 4m 0s                           airbus a319
# 28532 2022-05-23  18h 29m 0s  piper pa-61 aerostar (ted smith 601)
# 28533 2022-05-24  15h 40m 0s              de havilland dhc-3 otter
# 28534 2022-05-29   10h 7m 0s         de havilland dhc-6 twin otter
#
#                                      operator                   flight_phase  \
# 9071           united air services - tanzania  landing (descent or approach)
# 9075   lineas aéreas guerrero oaxaca - lagosa                takeoff (climb)
# 9081             new zealand national airways                        parking
# 9082             trans asiatic airlines - taa                takeoff (climb)
# 9086            central african airways - caa  landing (descent or approach)
# ...                                       ...                            ...
# 28529                    caverton helicopters                         flight
# 28530                          tibet airlines                takeoff (climb)
# 28532                    raul ignacion posada                         flight
# 28533                yakutat coastal airlines  landing (descent or approach)
# 28534                                tara air                         flight
#
#              flight_type                              crash_site  \
# 9071   passenger flights                           plain, valley
# 9075   passenger flights                           plain, valley
# 9081   passenger flights  airport (less than 10 km from airport)
# 9082   passenger flights  airport (less than 10 km from airport)
# 9086   passenger flights  airport (less than 10 km from airport)
# ...                  ...                                     ...
# 28529  passenger flights                           plain, valley
# 28530  passenger flights  airport (less than 10 km from airport)
# 28532  passenger flights                           plain, valley
# 28533  passenger flights  airport (less than 10 km from airport)
# 28534  passenger flights                               mountains
#
#                         schedule                               crash_location  \
# 9071                     unknown                     kazimzumbwi pwani region
# 9075                     unknown  mexico city federal district of mexico city
# 9081          rotorua – hamilton       rotorua bay of plenty regional council
# 9082                     unknown                         yangon yangon region
# 9086                     unknown                         livingstone southern
# ...                          ...                                          ...
# 28529  yaoundé – dompta – belabo                           nanga eboko centre
# 28530       chongqing – nyingchi                   chongqing-jiangbei sichuan
# 28532           celaya - durango                              durango durango
# 28533          yakutat – dry bay                               dry bay alaska
# 28534           pokhara – jomsom                           shikha dhawalagiri
#
#                         country           region  \
# 9071                   tanzania           africa
# 9075                     mexico  central america
# 9081                new zealand          oceania
# 9082                    myanmar             asia
# 9086                     zambia           africa
# ...                         ...              ...
# 28529                  cameroon           africa
# 28530                     china             asia
# 28532                    mexico  central america
# 28533  united states of america    north america
# 28534                     nepal             asia
#
#                                            circumstances        crash_cause  \
# 9071   while approaching dar es-salaam, the twin engi...            unknown
# 9075   few minutes after takeoff from mexico city, th...            unknown
# 9081   the aircraft was parked at rotorua airport and...  technical failure
# 9082   an undercarriage failed during takeoff roll. t...  technical failure
# 9086   crashed on final approach to livingstone airpo...            unknown
# ...                                                  ...                ...
# 28529  the twin engine airplane departed yaoundé at 1...            unknown
# 28530  the airplane was departing chongqing-jiangbei ...            unknown
# 28532  while approaching durango airport on a flight ...            unknown
# 28533  the single engine airplane departed yakutat on...            unknown
# 28534  the twin engine airplane departed pokhara city...       human factor
#
#        total_on_board  total_fatalities survivors
# 9071              2.0               2.0        no
# 9075              0.0               0.0   unknown
# 9081              5.0               0.0       yes
# 9082              0.0               0.0       yes
# 9086              0.0               0.0   unknown
# ...               ...               ...       ...
# 28529            11.0              11.0        no
# 28530           122.0               0.0       yes
# 28532             2.0               2.0        no
# 28533             4.0               0.0       yes
# 28534            22.0              22.0        no
#
# [10696 rows x 16 columns]

# %% [markdown]
# ## Charts

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences and sort in descending order
sorted_data = df_cleaned["crash_site"].value_counts()

# Convert the Series to a DataFrame
sorted_df = sorted_data.reset_index()
sorted_df.columns = ["crash_site", "count"]  # Rename columns for clarity

# Plot using the sorted data
sns.barplot(x="crash_site", y="count", data=sorted_df, palette="coolwarm_r")
plt.title("Crash Sites")
plt.xticks(rotation=90)
plt.xlabel("Crash Site")
plt.ylabel("Count")
plt.show()

# %%
df_cleaned["crash_site"].unique()
# Out:
# array(['plain, valley', 'airport (less than 10 km from airport)',
#        'mountains', 'lake, sea, ocean, river', 'desert', 'unknown',
#        'city'], dtype=object)

# %%
df_cleaned["flight_phase"].value_counts()
# Out:
# flight_phase
# landing (descent or approach)    4711
# flight                           3212
# takeoff (climb)                  2449
# unknown                           191
# taxiing                            84
# parking                            49
# Name: count, dtype: int64

# %% [markdown]
# # Bird Strike

# %% [markdown]
# ## Wrangling

# %%
df_cleaned.keys()
# Out:
# Index(['date', 'time', 'aircraft', 'operator', 'flight_phase', 'flight_type',
#        'crash_site', 'schedule', 'crash_location', 'country', 'region',
#        'circumstances', 'crash_cause', 'total_on_board', 'total_fatalities',
#        'survivors'],
#       dtype='object')

# %%
def circs(value):
        if 'bird' in value.lower():
            return 'bird'
        elif 'strike' in value.lower():
            return 'bird'
        else:
            return 'none'

# %%
df_cleaned["Cause"]=df_cleaned["circumstances"].apply(circs)

# %%
df_cleaned['Cause'].unique()
# Out:
# array(['none', 'bird'], dtype=object)

# %%
df_cleaned['Cause'].value_counts()
# Out:
# Cause
# none    10579
# bird      117
# Name: count, dtype: int64

# %% [markdown]
# ## Charts

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df_cleaned['Cause'], bins=100)
plt.title("Birdstrikes")
plt.xlabel("Birdstrikes")
plt.ylabel("Count of Type")
# Out:
# Text(0, 0.5, 'Count of Type')

# %%
df_loc_phase= df_cleaned[
    (df_cleaned["crash_site"].isin(["airport (less than 10 km from airport)"])) &
    (df_cleaned["flight_phase"].isin(["landing (descent or approach)","takeoff (climb)"]))
]
print(df_loc_phase)
# Out:
#             date        time                      aircraft  \
# 9082  1950-01-18     unknown                  douglas dc-3
# 9086  1950-01-22     unknown      de havilland dh.104 dove
# 9099  1950-02-05     unknown        douglas c-54 skymaster
# 9104  1950-02-09     unknown       canadair c-4 north star
# 9124  1950-03-07  20h 59m 0s                    martin 202
# ...          ...         ...                           ...
# 28507 2022-02-15     unknown       britten-norman islander
# 28517 2022-04-02  11h 19m 0s                    learjet 75
# 28526 2022-05-06  14h 18m 0s  cessna 421c golden eagle iii
# 28530 2022-05-12    8h 4m 0s                   airbus a319
# 28533 2022-05-24  15h 40m 0s      de havilland dhc-3 otter
#
#                                  operator                   flight_phase  \
# 9082         trans asiatic airlines - taa                takeoff (climb)
# 9086        central african airways - caa  landing (descent or approach)
# 9099                el al israel airlines                takeoff (climb)
# 9104   canadian pacific airlines - cp air  landing (descent or approach)
# 9124                   northwest airlines  landing (descent or approach)
# ...                                   ...                            ...
# 28507                        air flamenco  landing (descent or approach)
# 28517  georgia crown distributing company  landing (descent or approach)
# 28526                     private mexican                takeoff (climb)
# 28530                      tibet airlines                takeoff (climb)
# 28533            yakutat coastal airlines  landing (descent or approach)
#
#              flight_type                              crash_site  \
# 9082   passenger flights  airport (less than 10 km from airport)
# 9086   passenger flights  airport (less than 10 km from airport)
# 9099   passenger flights  airport (less than 10 km from airport)
# 9104   passenger flights  airport (less than 10 km from airport)
# 9124   passenger flights  airport (less than 10 km from airport)
# ...                  ...                                     ...
# 28507  passenger flights  airport (less than 10 km from airport)
# 28517  passenger flights  airport (less than 10 km from airport)
# 28526  passenger flights  airport (less than 10 km from airport)
# 28530  passenger flights  airport (less than 10 km from airport)
# 28533  passenger flights  airport (less than 10 km from airport)
#
#                                                 schedule  \
# 9082                                             unknown
# 9086                                             unknown
# 9099                                             unknown
# 9104                                   vancouver – tokyo
# 9124   washington-detroit-madison-rochester-minneapol...
# ...                                                  ...
# 28507                                 san juan - culebra
# 28517                               atlanta – morristown
# 28526                                  houston - mcallen
# 28530                               chongqing – nyingchi
# 28533                                  yakutat – dry bay
#
#                                           crash_location  \
# 9082                                yangon yangon region
# 9086                                livingstone southern
# 9099   lod (<u+05dc><u+05d5><u+05b9><u+05d3>) central...
# 9104                                  tokyo-haneda kanto
# 9124                               minneapolis minnesota
# ...                                                  ...
# 28507                     culebra island all puerto rico
# 28517                              morristown new jersey
# 28526                     houston-william p. hobby texas
# 28530                         chongqing-jiangbei sichuan
# 28533                                     dry bay alaska
#
#                         country           region  \
# 9082                    myanmar             asia
# 9086                     zambia           africa
# 9099                     israel             asia
# 9104                      japan             asia
# 9124   united states of america    north america
# ...                         ...              ...
# 28507               puerto rico  central america
# 28517  united states of america    north america
# 28526  united states of america    north america
# 28530                     china             asia
# 28533  united states of america    north america
#
#                                            circumstances        crash_cause  \
# 9082   an undercarriage failed during takeoff roll. t...  technical failure
# 9086   crashed on final approach to livingstone airpo...            unknown
# 9099   during the takeoff roll, the aircraft skidded,...            unknown
# 9104   after touchdown in haneda airport, the four en...            unknown
# 9124   the aircraft departed washington dc at 1230lt ...       human factor
# ...                                                  ...                ...
# 28507  upon landing on runway 13 at culebra airport, ...            unknown
# 28517  following an uneventful flight from atlanta-fu...            unknown
# 28526  while taking off from houston-william p. hobby...  technical failure
# 28530  the airplane was departing chongqing-jiangbei ...            unknown
# 28533  the single engine airplane departed yakutat on...            unknown
#
#        total_on_board  total_fatalities survivors Cause
# 9082              0.0               0.0       yes  none
# 9086              0.0               0.0   unknown  none
# 9099             50.0               0.0       yes  none
# 9104             15.0               0.0       yes  none
# 9124             13.0               0.0        no  none
# ...               ...               ...       ...   ...
# 28507             0.0               0.0       yes  none
# 28517             4.0               0.0       yes  none
# 28526             4.0               0.0       yes  none
# 28530           122.0               0.0       yes  none
# 28533             4.0               0.0       yes  none
#
# [5360 rows x 17 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="flight_phase", hue="crash_site", data=df_loc_phase, palette="viridis")
plt.title("Crashes During Phases of Flight within 10km of Airport")
plt.xlabel("Phase")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.legend().remove()  # Correct way to remove the legend
plt.show()

# %%
df = df_loc_phase["flight_phase"].value_counts()
print(df)
# Out:
# flight_phase
# landing (descent or approach)    3576
# takeoff (climb)                  1784
# Name: count, dtype: int64

# %%
df = df_loc_phase["flight_phase"].value_counts()
plt.bar(df.index, df.values, color=["skyblue", "salmon"])
plt.title("Number of Crashes by Flight Phase")
plt.xlabel("Flight Phase")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')  # Adjust for better readability
plt.show()

# %% [markdown]
# # Crashes by country

# %% [markdown]
# ## Wrangling

# %%
df_cleaned.sort_values(by="country", ascending=False)
df_cleaned
# Out:
#             date        time                              aircraft  \
# 9071  1950-01-03     unknown                        avro 652 anson
# 9075  1950-01-07     unknown                            boeing 247
# 9081  1950-01-14     unknown      de havilland dh.89 dragon rapide
# 9082  1950-01-18     unknown                          douglas dc-3
# 9086  1950-01-22     unknown              de havilland dh.104 dove
# ...          ...         ...                                   ...
# 28529 2022-05-11     unknown         de havilland dhc-6 twin otter
# 28530 2022-05-12    8h 4m 0s                           airbus a319
# 28532 2022-05-23  18h 29m 0s  piper pa-61 aerostar (ted smith 601)
# 28533 2022-05-24  15h 40m 0s              de havilland dhc-3 otter
# 28534 2022-05-29   10h 7m 0s         de havilland dhc-6 twin otter
#
#                                      operator                   flight_phase  \
# 9071           united air services - tanzania  landing (descent or approach)
# 9075   lineas aéreas guerrero oaxaca - lagosa                takeoff (climb)
# 9081             new zealand national airways                        parking
# 9082             trans asiatic airlines - taa                takeoff (climb)
# 9086            central african airways - caa  landing (descent or approach)
# ...                                       ...                            ...
# 28529                    caverton helicopters                         flight
# 28530                          tibet airlines                takeoff (climb)
# 28532                    raul ignacion posada                         flight
# 28533                yakutat coastal airlines  landing (descent or approach)
# 28534                                tara air                         flight
#
#              flight_type                              crash_site  \
# 9071   passenger flights                           plain, valley
# 9075   passenger flights                           plain, valley
# 9081   passenger flights  airport (less than 10 km from airport)
# 9082   passenger flights  airport (less than 10 km from airport)
# 9086   passenger flights  airport (less than 10 km from airport)
# ...                  ...                                     ...
# 28529  passenger flights                           plain, valley
# 28530  passenger flights  airport (less than 10 km from airport)
# 28532  passenger flights                           plain, valley
# 28533  passenger flights  airport (less than 10 km from airport)
# 28534  passenger flights                               mountains
#
#                         schedule                               crash_location  \
# 9071                     unknown                     kazimzumbwi pwani region
# 9075                     unknown  mexico city federal district of mexico city
# 9081          rotorua – hamilton       rotorua bay of plenty regional council
# 9082                     unknown                         yangon yangon region
# 9086                     unknown                         livingstone southern
# ...                          ...                                          ...
# 28529  yaoundé – dompta – belabo                           nanga eboko centre
# 28530       chongqing – nyingchi                   chongqing-jiangbei sichuan
# 28532           celaya - durango                              durango durango
# 28533          yakutat – dry bay                               dry bay alaska
# 28534           pokhara – jomsom                           shikha dhawalagiri
#
#                         country           region  \
# 9071                   tanzania           africa
# 9075                     mexico  central america
# 9081                new zealand          oceania
# 9082                    myanmar             asia
# 9086                     zambia           africa
# ...                         ...              ...
# 28529                  cameroon           africa
# 28530                     china             asia
# 28532                    mexico  central america
# 28533  united states of america    north america
# 28534                     nepal             asia
#
#                                            circumstances        crash_cause  \
# 9071   while approaching dar es-salaam, the twin engi...            unknown
# 9075   few minutes after takeoff from mexico city, th...            unknown
# 9081   the aircraft was parked at rotorua airport and...  technical failure
# 9082   an undercarriage failed during takeoff roll. t...  technical failure
# 9086   crashed on final approach to livingstone airpo...            unknown
# ...                                                  ...                ...
# 28529  the twin engine airplane departed yaoundé at 1...            unknown
# 28530  the airplane was departing chongqing-jiangbei ...            unknown
# 28532  while approaching durango airport on a flight ...            unknown
# 28533  the single engine airplane departed yakutat on...            unknown
# 28534  the twin engine airplane departed pokhara city...       human factor
#
#        total_on_board  total_fatalities survivors Cause
# 9071              2.0               2.0        no  none
# 9075              0.0               0.0   unknown  none
# 9081              5.0               0.0       yes  none
# 9082              0.0               0.0       yes  none
# 9086              0.0               0.0   unknown  none
# ...               ...               ...       ...   ...
# 28529            11.0              11.0        no  none
# 28530           122.0               0.0       yes  none
# 28532             2.0               2.0        no  none
# 28533             4.0               0.0       yes  none
# 28534            22.0              22.0        no  none
#
# [10696 rows x 17 columns]

# %% [markdown]
# ## Charts

# %%
df_cleaned['country'].value_counts().head(20)
import matplotlib.pyplot as plt
top_20_countries = df_cleaned['country'].value_counts().head(20)
plt.bar(top_20_countries.index, top_20_countries.values, color="skyblue")
plt.title("Number of Crashes by Country")
plt.xlabel("Country")
plt.ylabel("Count")
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# # Aircraft Sizes

# %% [markdown]
# ## Import

# %%
df_aircrafts = pd.read_excel('/Users/haydnjones/Documents/GitHub/flight-crashes/aircraft_data.xlsx')
df_aircrafts = pd.DataFrame(df_aircrafts)

df_aircrafts = df_aircrafts.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df_aircrafts.columns = pd.Series(df_aircrafts.columns).apply(lambda col: col.lower())
df_aircrafts.dropna(how='all', inplace= True)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /opt/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():

# %% [markdown]
# ## Cleaning

# %%
df_aircrafts = df_aircrafts.drop_duplicates(subset='model_faa')

# %% [markdown]
# ## Wrangling

# %%
df_cleaned_aircrafts = df_cleaned

# %%
df_aircrafts = df_aircrafts[['model_faa', 'length_ft', 'class']]

# %%
standard_aircraft_names = df_aircrafts['model_faa'].tolist()

# %%
def get_best_match(aircraft_name, choices, threshold=90):
    # Use extract to get top 3 matches
    matches = process.extract(aircraft_name, choices, limit=3)
    
    best_match = next((match for match in matches if match[1] >= threshold), None)
    
    return best_match[0] if best_match else None

df_cleaned_aircrafts['model_faa'] = df_cleaned_aircrafts['aircraft'].apply(lambda x: get_best_match(x, standard_aircraft_names))

# %%
df_cleaned_aircrafts = df_cleaned_aircrafts [['date', 'model_faa', 'flight_phase', 'crash_site', 'country', 'total_on_board', 'total_fatalities']]

# %%
df_cleaned_aircrafts = df_cleaned_aircrafts.dropna(subset=['model_faa'])

# %%
df_cleaned_aircrafts
# Out:
#             date                model_faa                   flight_phase  \
# 9082  1950-01-18             douglas dc 3                takeoff (climb)
# 9210  1950-06-09             douglas dc 3                         flight
# 9214  1950-06-13             douglas dc 3  landing (descent or approach)
# 9216  1950-06-15             douglas dc 3  landing (descent or approach)
# 9226  1950-06-23             douglas dc 3                         flight
# ...          ...                      ...                            ...
# 28517 2022-04-02               learjet 75  landing (descent or approach)
# 28519 2022-04-06               cessna 340  landing (descent or approach)
# 28523 2022-04-20  cessna 207 stationair 7                takeoff (climb)
# 28524 2022-04-21               cessna 340                takeoff (climb)
# 28530 2022-05-12              airbus a319                takeoff (climb)
#
#                                    crash_site                   country  \
# 9082   airport (less than 10 km from airport)                   myanmar
# 9210                                mountains                  colombia
# 9214                  lake, sea, ocean, river                   bahrain
# 9216                  lake, sea, ocean, river                   bahrain
# 9226                  lake, sea, ocean, river  united states of america
# ...                                       ...                       ...
# 28517  airport (less than 10 km from airport)  united states of america
# 28519                           plain, valley                    mexico
# 28523                                    city                     haiti
# 28524                                    city  united states of america
# 28530  airport (less than 10 km from airport)                     china
#
#        total_on_board  total_fatalities
# 9082              0.0               0.0
# 9210             15.0              15.0
# 9214             52.0              46.0
# 9216             53.0              40.0
# 9226             58.0               3.0
# ...               ...               ...
# 28517             4.0               0.0
# 28519             1.0               0.0
# 28523             5.0               6.0
# 28524             2.0               2.0
# 28530           122.0               0.0
#
# [3222 rows x 7 columns]

# %%
df_aircrafts
# Out:
#                  model_faa  length_ft       class
# 0            fairchild a10       53.3  fixed-wing
# 1    antonov an-124 ruslan      226.2  fixed-wing
# 2          airbus a319 neo      111.0  fixed-wing
# 3          airbus a320 neo      123.3  fixed-wing
# 4          airbus a321 neo      146.0  fixed-wing
# ..                     ...        ...         ...
# 383         socata tbm-900       35.2  fixed-wing
# 384       raytheon texan 2       33.2  fixed-wing
# 385    socata tb-10 tobago       25.4  fixed-wing
# 386       bell v-22 osprey       63.0   tiltrotor
# 387      iai 1124 westwind       52.3  fixed-wing
#
# [388 rows x 3 columns]

# %%
df_aircrafts_crashed = pd.merge(df_cleaned_aircrafts, df_aircrafts, on='model_faa', how='left')

# %%
df_aircrafts_crashed
# Out:
#            date                model_faa                   flight_phase  \
# 0    1950-01-18             douglas dc 3                takeoff (climb)
# 1    1950-06-09             douglas dc 3                         flight
# 2    1950-06-13             douglas dc 3  landing (descent or approach)
# 3    1950-06-15             douglas dc 3  landing (descent or approach)
# 4    1950-06-23             douglas dc 3                         flight
# ...         ...                      ...                            ...
# 3217 2022-04-02               learjet 75  landing (descent or approach)
# 3218 2022-04-06               cessna 340  landing (descent or approach)
# 3219 2022-04-20  cessna 207 stationair 7                takeoff (climb)
# 3220 2022-04-21               cessna 340                takeoff (climb)
# 3221 2022-05-12              airbus a319                takeoff (climb)
#
#                                   crash_site                   country  \
# 0     airport (less than 10 km from airport)                   myanmar
# 1                                  mountains                  colombia
# 2                    lake, sea, ocean, river                   bahrain
# 3                    lake, sea, ocean, river                   bahrain
# 4                    lake, sea, ocean, river  united states of america
# ...                                      ...                       ...
# 3217  airport (less than 10 km from airport)  united states of america
# 3218                           plain, valley                    mexico
# 3219                                    city                     haiti
# 3220                                    city  united states of america
# 3221  airport (less than 10 km from airport)                     china
#
#       total_on_board  total_fatalities  length_ft       class
# 0                0.0               0.0       64.7  fixed-wing
# 1               15.0              15.0       64.7  fixed-wing
# 2               52.0              46.0       64.7  fixed-wing
# 3               53.0              40.0       64.7  fixed-wing
# 4               58.0               3.0       64.7  fixed-wing
# ...              ...               ...        ...         ...
# 3217             4.0               0.0       58.0  fixed-wing
# 3218             1.0               0.0       43.3  fixed-wing
# 3219             5.0               6.0       31.5  fixed-wing
# 3220             2.0               2.0       43.3  fixed-wing
# 3221           122.0               0.0      111.0  fixed-wing
#
# [3222 rows x 9 columns]

# %%
df_aircrafts_crashed['size_cat'] = df_aircrafts_crashed['length_ft'].apply(
    lambda x: 'small_aircraft' if x <= 100 else ('medium_aircraft' if 100 < x <= 180 else 'large_aircraft')
)

# %%
df_aircrafts_crashed['size_cat'].value_counts()
# Out:
# size_cat
# small_aircraft     2161
# medium_aircraft     972
# large_aircraft       89
# Name: count, dtype: int64

# %%
df_aircrafts_crashed
# Out:
#            date                model_faa                   flight_phase  \
# 0    1950-01-18             douglas dc 3                takeoff (climb)
# 1    1950-06-09             douglas dc 3                         flight
# 2    1950-06-13             douglas dc 3  landing (descent or approach)
# 3    1950-06-15             douglas dc 3  landing (descent or approach)
# 4    1950-06-23             douglas dc 3                         flight
# ...         ...                      ...                            ...
# 3217 2022-04-02               learjet 75  landing (descent or approach)
# 3218 2022-04-06               cessna 340  landing (descent or approach)
# 3219 2022-04-20  cessna 207 stationair 7                takeoff (climb)
# 3220 2022-04-21               cessna 340                takeoff (climb)
# 3221 2022-05-12              airbus a319                takeoff (climb)
#
#                                   crash_site                   country  \
# 0     airport (less than 10 km from airport)                   myanmar
# 1                                  mountains                  colombia
# 2                    lake, sea, ocean, river                   bahrain
# 3                    lake, sea, ocean, river                   bahrain
# 4                    lake, sea, ocean, river  united states of america
# ...                                      ...                       ...
# 3217  airport (less than 10 km from airport)  united states of america
# 3218                           plain, valley                    mexico
# 3219                                    city                     haiti
# 3220                                    city  united states of america
# 3221  airport (less than 10 km from airport)                     china
#
#       total_on_board  total_fatalities  length_ft       class         size_cat
# 0                0.0               0.0       64.7  fixed-wing   small_aircraft
# 1               15.0              15.0       64.7  fixed-wing   small_aircraft
# 2               52.0              46.0       64.7  fixed-wing   small_aircraft
# 3               53.0              40.0       64.7  fixed-wing   small_aircraft
# 4               58.0               3.0       64.7  fixed-wing   small_aircraft
# ...              ...               ...        ...         ...              ...
# 3217             4.0               0.0       58.0  fixed-wing   small_aircraft
# 3218             1.0               0.0       43.3  fixed-wing   small_aircraft
# 3219             5.0               6.0       31.5  fixed-wing   small_aircraft
# 3220             2.0               2.0       43.3  fixed-wing   small_aircraft
# 3221           122.0               0.0      111.0  fixed-wing  medium_aircraft
#
# [3222 rows x 10 columns]

# %% [markdown]
# ## Charts

# %%
df_aircrafts_crashed
